# %% [markdown]
# <a href="https://colab.research.google.com/github/jyryu3161/biocomputing/blob/main/lab5_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab5.파이썬 프로그래밍 함수

# %% [markdown]
# ## 함수

# %% [markdown]
# 함수의 구조

# %%
def 함수명(매개변수):
    <수행할 문장1>
    <수행할 문장2>

return 리턴 값

# %% [markdown]
# 일반적인 함수 정의

# %%
def sum(a, b):
    result = a + b
    return result

a = sum(3, 4)
print (a)

a = sum(30, 40)
print (a)

a = sum(23, 14)
print (a)

# %% [markdown]
# 코드의 흐름

# %%
print('1')
def sum(a, b):
    a = 10
    print('2')
    result = a + b
    return result

print('3')
a = sum(3, 4)
print('4')
print(a)

# %% [markdown]
# 전역변수, 지역변수

# %% [markdown]
# 입력값이 없는 함수

# %%
def say():
    return 'Hi'

a = say()
print(a)

# %% [markdown]
# 리턴(결과)값이 없는 함수

# %%
def sum(a, b):
    print("%d, %d의 합은 %d입니다." % (a, b, a+b))

# sum(3, 4)

# result = sum(3, 4)
# print(result)


a = [1, 3, 5, 7, 9]
b = a.reverse()
print(b)

# %% [markdown]
# 입력값도 결과값도 없는 함수

# %%
def say():
    print('Hi')

say()

# %% [markdown]
# 함수의 결과값을 받는 방법들

# %%
def sum_and_mul(a,b):
	return a+b, a*b

result = sum_and_mul(3,4)
print(result)

sum_val = result[0]
mul_val = result[1]
print (sum_val, mul_val)

# %%
def sum_and_mul(a,b):
	return a+b, a*b

sum_val, mul_val = sum_and_mul(3,4)
print(sum_val, mul_val)

# %% [markdown]
# 매개변수에 초깃값을 설정하는 방법

# %%
def say_myself(name, old, man=True):
    print("나의 이름은 %s 입니다." % name)
    print("나이는 %d살입니다." % old)
    if man:
        print("남자입니다.")
    else:
        print("여자입니다.")

say_myself("박응용", 27)
say_myself("박응용", 27, True)

# %% [markdown]
# 함수 매개 변수에 초깃값을 설정할 때 주의할 사항

# %%
def say_myself(name, man=True, old):
    print("나의 이름은 %s 입니다." % name)
    print("나이는 %d살입니다." % old)
    if man:
        print("남자입니다.")
    else:
        print("여자입니다.")

say_myself("박응용", 27)
say_myself("박응용", 27, True)

# %% [markdown]
# 함수 안에서 선언된 변수의 효력 범위

# %%
a = 1
def vartest(a):
    a = a + 1

vartest(a)
print(a)

# %%
def sum(a, b):
    result = a + b
    return result

a = 3
b = 5
a = sum(a, b)

# %%
a = 1
def vartest():
    global a
    a = a + 1

vartest()
print(a)

# %% [markdown]
# ## 내장함수

# %%
abs(3)
all([1, 2, 3])
any([1, 2, 3, 0])
dir([1, 2, 3])
divmod(7, 3)

# data = ['body', 'foo', 'bar']
# for i in range(len(data)):
# 	print(i, data[i])

for i, name in enumerate(['body', 'foo', 'bar']):
	print(i, name)

# a = 3
# id(a)
# pow(2, 4)

# %% [markdown]
# ## 외장함수

# %%
import time

print(time.time())
print(time.localtime(time.time()))

# %%
import random
print(random.random()) # 0~1 사이의 난수
print(random.randint(1, 10))

data = [1, 2, 3, 4, 5]
random.shuffle(data)
print(data)

# %% [markdown]
# ## 실습 문제

# %% [markdown]
# 1. 다음 코드를 참고하여 하나의 정수를 함수의 입력으로 받아, 소수인지 아닌지를 판단하는 함수 코드를 작성하세요. 소수인 경우 return 값으로 True, 소수가 아닌 경우 return 값으로 False를 반환하세요.

# %% [markdown]
# 2. 숫자로 구성된 리스트를 함수의 입력으로 받고, 해당 리스트의 합을 모두 계산하여 반환하는 함수를 작성하세요.
