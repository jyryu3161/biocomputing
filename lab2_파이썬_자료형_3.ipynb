# %% [markdown]
# <a href="https://colab.research.google.com/github/jyryu3161/biocomputing/blob/main/lab2_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%9E%90%EB%A3%8C%ED%98%95_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab2.파이썬 프로그래밍 기초, 자료형

# %% [markdown]
# ## 딕셔너리 자료형

# %% [markdown]
# *  딕셔너리 자료형: key와 value를 한 쌍으로 갖는 자료형
# *  my_dic = {Key1: value1, Key2: value2, key3: value3 … }

# %%
my_dic = {'name': 'pey', 'phone': '0119993323', 'birth': '1118'}

print (my_dic['name'])
print (my_dic['phone'])
print (my_dic['birth'])
# Out:
# pey
# 0119993323
# 1118

# %% [markdown]
# * 딕셔너리의 value로 리스트를 넣을 수 있고, 딕셔너리의 key로 튜플을 넣을 수 있음
# * 딕셔너리의 value로 또 다른 딕셔너리가 들어갈 수 있음

# %%
a = {('a', 1): 'b'}
print (a)
print (a[('a', 1)]) # => 'b'

a = {'a':[1,2,3]}
print (a['a'])

a = {'a':{'b': 1}}
print (a['a'])

# {'b': 1}
a2 = a['a']
a2 = {'b': 1}
print (a['a']['b']) # => 1
print (a['a']['b']) # => 1
# Out:
# {('a', 1): 'b'}
# b
# [1, 2, 3]
# {'a': {'b': 1}}
# {'b': 1}
# 1

# %% [markdown]
# 딕셔너리 쌍 추가하기, 요소 제거하기

# %%
a = {}
a[1] = 'a'
a[2] = 'b'
print (a)

del a[1]
print (a)
# Out:
# {1: 'a', 2: 'b'}
# {2: 'b'}

# %% [markdown]
# 딕셔너리에서 key 사용하여 value 얻기

# %%
grade = {'pey': 10}

print (grade['pey'])

grade = {}
grade['pey'] = 10

print (grade['pey'])
# Out:
# 10
# 10

# %% [markdown]
# 딕셔너리 만들 때 주의사항

# %%
a = {1:'a', 1:'b'}

a = {}
a[1] = 'a'
a[1] = 'b'

print (a)
print (a[1])
# Out:
# {1: 'b'}
# b

# %% [markdown]
# Key, value 쌍을 얻기(items)

# %%
a = {'name':'pey', 'phone':'0119993323', 'birth':'1118'}

print (a.keys())
print (a.values())
print (a.items())
# Out:
# dict_keys(['name', 'phone', 'birth'])
# dict_values(['pey', '0119993323', '1118'])
# dict_items([('name', 'pey'), ('phone', '0119993323'), ('birth', '1118')])

# %% [markdown]
# Key, value 쌍 모두 지우기(clear)

# %%
a = {'name':'pey', 'phone':'0119993323', 'birth':'1118'}
print (a.items())
a.clear()
print (a)
# Out:
# dict_items([('name', 'pey'), ('phone', '0119993323'), ('birth', '1118')])
# {}

# %% [markdown]
# Key로 value 얻기

# %%
a = {'name':'pey', 'phone':'0119993323', 'birth':'1118'}
print(a.get('name'))
print(a['name']) # 같은 문법
# Out:
# pey
# pey

# %% [markdown]
# 해당 key가 딕셔너리 안에 있는지 조사하기 (in)

# %%
a = {'name':'pey', 'phone':'0119993323', 'birth':'1118'}
print('name' in a)
print('email' in a)

print(a['email'])
# Out:
# True
# False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6f7451d38d96> in <module>
#       3 print('email' in a)
#       4
# ----> 5 print(a['email'])
#
# KeyError: 'email'

# %% [markdown]
# 딕셔너리 사용 예

# %%
codon_dict = {'UUU':'Phe','UUC':'Phe','uua':'Leu','UUG':'Leu','CUU':'Leu','CUC':'Leu','CUA':'Leu','CUG':'Leu','AUU':'Ile','AUC':'Ile','AUA':'Ile','AUG':'Met','GUU':'Val','GUC':'Val','GUA':'Val','GUG':'Val','UCU':'Ser','UCC':'Ser','UCA':'Ser','UCG':'Ser','CCU':'Pro','CCC':'Pro','CCA':'Pro','CCG':'Pro','ACU':'Thr','ACC':'Thr','ACA':'Thr','ACG':'Thr','GCU':'Ala','GCC':'Ala','GCA':'Ala','GCG':'Ala','UAU':'Tyr','UAC':'Tyr','UAA':'STOP','UAG':'STOP','CAU':'His','CAC':'His','CAA':'Gln','CAG':'Gln','AAU':'Asn','AAC':'Asn','AAA':'Lys','AAG':'Lys','GAU':'Asp','GAC':'Asp','GAA':'Glu','GAG':'Glu','UGU':'Cys','UGC':'Cys','UGA':'STOP','UGG':'Trp','CGU':'Arg','CGC':'Arg','CGA':'Arg','CGG':'Arg','AGU':'Ser','AGC':'Ser','AGA':'Arg','AGG':'Arg','GGU':'Gly','GGC':'Gly','GGA':'Gly','GGG':'Gly'}
seq = 'UUUCUU'

codon1 = seq[0:3]
print(codon_dict[codon1])

codon2 = seq[3:6]
print(codon_dict[codon2])
# Out:
# Phe
# Leu

# %% [markdown]
# # 문제

# %% [markdown]
# * 다음 codon table을 이용하여 dictionary 2개를 만들어라.
# * RNA가 key, Amino acid가 value인 dictionary 1개
# * Amino acid가 key, RNA가 values (list)인 dictionary 1개

# %% [markdown]
# ![The-codon-table-The-genetic-code-is-composed-of-four-different-letters-U-C-A-and-G.png](data:image/png;base64,...)
